# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSH0205-create/LetsGrowMore_Internship2021/blob/main/Task2_LGMVIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 2: Image to pencil sketch with python**

# %% [markdown]
# In this task of** LGMVIP**, I have converted my colored image to grayscale then inverted the grayscale image to get a negative and further by applying a gaussian blur to the negative and inverting it I got the final **pencil sketch** of my image.

# %%
#importing the library
from google.colab.patches import cv2_imshow
import cv2

# %%
#loading the respective image
image = cv2.imread("harsh.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=360x480 at 0x7F7871BB4E10>

# %%
#conversion to gray scale image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=360x480 at 0x7F7871B53D50>

# %%
# Inverting the grayscale image or transforming into negative using bitwise_not operator
image_invert = cv2.bitwise_not(image_gray)
cv2_imshow(image_invert)
# Out:
# <PIL.Image.Image image mode=L size=360x480 at 0x7F7871B5FF10>

# %%
#blurring the image using gaussian function
blurred = cv2.GaussianBlur(image_invert, (21, 21), 0)

# %%
#inverting the blurred image
blurred_invert = 255-blurred

# %%
#final sketch
final_sketch = cv2.divide(image_gray, blurred_invert, scale=256.0)
cv2_imshow(final_sketch)
# Out:
# <PIL.Image.Image image mode=L size=360x480 at 0x7F7870AA88D0>
